# %%
import numpy as np
import cv2
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("img.png", 0)
print(img.shape)
cv2.imwrite("img1.png", img)
cv2_imshow(img)
# Out:
# (729, 1094)
# <PIL.Image.Image image mode=L size=1094x729 at 0x7F56B927DAC8>

# %%
img = cv2.imread("label.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1094x729 at 0x7F56B9134BE0>
